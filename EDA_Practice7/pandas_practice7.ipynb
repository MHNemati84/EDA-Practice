# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("top-5000-youtube-channels.csv")

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %% [markdown]
# ## 1. Display all rows except the last 5 rows using the head method

# %%
data.head(-5)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %% [markdown]
# ## 2. Display all rows except the first 5 rows using the tail method

# %%
data.tail(-5)
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  \
# 5         6th  A++              Movieclips         30243    17149705
# 6         7th  A++              netd müzik          8500    11373567
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206
# 8         9th  A++         Ryan ToysReview          1140    16082927
# 9        10th  A++             Zee Marathi         74607     2841811
# ...       ...   ...                    ...           ...         ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+             Mastersaint           110     3265735
# 4998  4,999th   B+          Bruce McIntosh          3475       32990
# 4999  5,000th   B+               SehatAQUA           254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...           ...
# ...

# %% [markdown]
# ## 3. Find the shape of the dataset

# %%
data.shape
# Out:
# (5000, 6)

# %% [markdown]
# ## 4. General info about the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %% [markdown]
# ## 5. Overall Statistics about the dataset

# %%
data.describe()
# Out:
#         Video views
# count  5.000000e+03
# mean   1.071449e+09
# std    2.003844e+09
# min    7.500000e+01
# 25%    1.862329e+08
# 50%    4.820548e+08
# 75%    1.124368e+09
# max    4.754884e+10

# %% [markdown]
# ## 6. Data Cleaning (Replacing '--' with NaN)

# %%
data.tail(20)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 4980  4,981st   B+                     Screen Junkies           878
# 4981  4,982nd   B+                         Luli60able             5
# 4982  4,983rd   B+                           채널A Home          9876
# 4983  4,984th   B+                    Машинка Игрушка           242
# 4984  4,985th   B+                             Jean L          2116
# 4985  4,986th   B+                  AndreaBocelliVEVO           191
# 4986  4,987th   B+                 CidadeAlertaRecord          7299
# 4987  4,988th   B+                      YouANDi Games          1358
# 4988  4,989th   B+             GREAT IDEAS GREAT LIFE            80
# 4989  4,990th   B+                             Kukuli           219
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# ...

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
data.iloc[17]['Subscribers']
# Out:
# '-- '

# %%
data.replace('-- ', np.nan, inplace=True)

# %%
# Alternalively
data.replace('--', np.nan, inplace=True)

# %%
data['Subscribers'].str.contains('--').sum()
# Out:
# 0

# %% [markdown]
# ## 7. Checking the null values in the dataset

# %%
data.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
data.isnull().sum() * 100 / data.shape[0]
# Out:
# Rank             0.00
# Grade            0.00
# Channel name     0.00
# Video Uploads    0.12
# Subscribers      7.74
# Video views      0.00
# dtype: float64

# %%
data.dropna(axis=0, inplace=True)

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# ## 8. Data Cleaning and Encoding (Rank Column)

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
data['Rank'] = data['Rank'].str.replace(',', '')

# %%
data['Rank'] = data['Rank'].apply(lambda x: x[:-2])

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1  A++                       Zee TV         82757    18752951
# 1    2  A++                     T-Series         12661    61196302
# 2    3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4  A++                    SET India         27323    31180559
# 4    5  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail()
# Out:
#       Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4996   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4997   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4998   B+         Mastersaint           110     3265735    311758426
# 4998  4999   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5000   B+           SehatAQUA           254       21172     73312511

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
data['Rank'] = data['Rank'].astype('int')

# %%
data.dtypes
# Out:
# Rank              int64
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %% [markdown]
# ## 9. Data Cleaning and Encoding (Video Uploads and Subscribers)

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0      1  A++                       Zee TV         82757    18752951
# 1      2  A++                     T-Series         12661    61196302
# 2      3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3      4  A++                    SET India         27323    31180559
# 4      5  A++                          WWE         36756    32852346
# 5      6  A++                   Movieclips         30243    17149705
# 6      7  A++                   netd müzik          8500    11373567
# 7      8  A++        ABS-CBN Entertainment        100147    12149206
# 8      9  A++              Ryan ToysReview          1140    16082927
# 9     10  A++                  Zee Marathi         74607     2841811
# 10    11   A+              5-Minute Crafts          2085    33492951
# 11    12   A+              Canal KondZilla           822    39409726
# 12    13   A+             Like Nastya Vlog           150     7662886
# ...

# %%
data.tail(20)
# Out:
#       Rank Grade                      Channel name Video Uploads Subscribers  \
# 4979  4980   B+                          MonkeyBoo           707     1558006
# 4980  4981   B+                     Screen Junkies           878     6532616
# 4981  4982   B+                         Luli60able             5      158905
# 4982  4983   B+                           채널A Home          9876      647435
# 4983  4984   B+                    Машинка Игрушка           242      219238
# 4984  4985   B+                             Jean L          2116     2875705
# 4985  4986   B+                  AndreaBocelliVEVO           191      820381
# 4986  4987   B+                 CidadeAlertaRecord          7299     1123300
# 4987  4988   B+                      YouANDi Games          1358     1536819
# 4988  4989   B+             GREAT IDEAS GREAT LIFE            80     1349511
# 4989  4990   B+                             Kukuli           219      660742
# ...

# %%
data.dtypes
# Out:
# Rank              int64
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
data[['Video Uploads', 'Subscribers']] = data[['Video Uploads', 'Subscribers']].astype('int')

# %%
data.dtypes
# Out:
# Rank              int64
# Grade            object
# Channel name     object
# Video Uploads     int64
# Subscribers       int64
# Video views       int64
# dtype: object

# %% [markdown]
# ## 10. Data Cleaning and Encoding(Grade Column)

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name  Video Uploads  Subscribers  \
# 0      1  A++                       Zee TV          82757     18752951
# 1      2  A++                     T-Series          12661     61196302
# 2      3  A++   Cocomelon - Nursery Rhymes            373     19238251
# 3      4  A++                    SET India          27323     31180559
# 4      5  A++                          WWE          36756     32852346
# 5      6  A++                   Movieclips          30243     17149705
# 6      7  A++                   netd müzik           8500     11373567
# 7      8  A++        ABS-CBN Entertainment         100147     12149206
# 8      9  A++              Ryan ToysReview           1140     16082927
# 9     10  A++                  Zee Marathi          74607      2841811
# 10    11   A+              5-Minute Crafts           2085     33492951
# 11    12   A+              Canal KondZilla            822     39409726
# ...

# %%
data.tail(20)
# Out:
#       Rank Grade                      Channel name  Video Uploads  \
# 4979  4980   B+                          MonkeyBoo            707
# 4980  4981   B+                     Screen Junkies            878
# 4981  4982   B+                         Luli60able              5
# 4982  4983   B+                           채널A Home           9876
# 4983  4984   B+                    Машинка Игрушка            242
# 4984  4985   B+                             Jean L           2116
# 4985  4986   B+                  AndreaBocelliVEVO            191
# 4986  4987   B+                 CidadeAlertaRecord           7299
# 4987  4988   B+                      YouANDi Games           1358
# 4988  4989   B+             GREAT IDEAS GREAT LIFE             80
# 4989  4990   B+                             Kukuli            219
# 4991  4992   B+               Toys to Learn Colors             11
# 4992  4993   B+                              КАZКА             25
# ...

# %%
data['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
data['Grade'] = data['Grade'].map({'A++ ':5, 'A+ ':4, 'A ':3, 'A- ':2, 'B+ ':1})

# %% [markdown]
# ## 11. Average views for each channel

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data.groupby('Channel name')['Video views'].mean()
# Out:
# Channel name
# #Desenhos Kids BR               8.404115e+07
# #FIRST WINGS FILM PRODUCTION    1.267895e+07
# #Mentale Zuflucht               3.634114e+08
# #Mind Warehouse                 1.337877e+09
# #Refugio Mental                 1.262197e+09
#                                     ...
# 핑크퐁 (인기 동요・동화)                  1.595353e+09
# 허팝Heopop                        1.690027e+09
# 헤이지니 Hey Jini                   4.550237e+08
# 헬로카봇 - hello carbot…            3.291915e+08
# 흔한남매                            1.196532e+08
# Name: Video views, Length: 4604, dtype: float64

# %% [markdown]
# ## 12. Top five channels with the most video uploads

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data.sort_values(by='Video Uploads', ascending=False).head()[['Channel name', 'Video Uploads']]
# Out:
#      Channel name  Video Uploads
# 3453   AP Archive         422326
# 1149     YTN NEWS         355996
# 2223    SBS Drama         335521
# 323      GMA News         269065
# 2956          MLB         267649

# %% [markdown]
# ## 13. Correlation Matrix

# %%
sns.heatmap(data.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[217], line 1
# ----> 1 sns.heatmap(data.corr())
#
# File c:\Users\mohammad1384\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\mohammad1384\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
# ...
