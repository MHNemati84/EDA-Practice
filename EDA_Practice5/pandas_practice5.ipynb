# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("udemy_courses.csv", parse_dates=['published_timestamp'])

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %% [markdown]
# ## 1. Display the top 10 rows of the dataset

# %%
data.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %%
data.tail()
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# ## 3. Shape of the dataset

# %%
data.shape
# Out:
# (3678, 12)

# %% [markdown]
# ## 4. General Info about the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %% [markdown]
# ## 5. Number of Null values in the columns

# %%
data.isnull().sum(axis=0)
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ## 6. Check for duplicates and drop them

# %%
print("Any Duplicates? ", data.duplicated().values.any())
# Out:
# Any Duplicates?  True

# %%
(data.duplicated() == True).sum()
# Out:
# np.int64(6)

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# ## 7. Number of Courses Per Subject

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
sns.countplot(x='subject', data=data)
plt.xlabel("Subject Name", fontsize=13)
plt.ylabel("Number of Courses Per Subject", fontsize=13)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 7. For which levels is Udemy providing the courses?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['level'].unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
data['level'].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
sns.countplot(data=data, x='level')
plt.xlabel("Level", fontsize=13)
plt.ylabel("Count", fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## 8. Display the count of free and paid courses

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['is_paid'].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %%
sns.countplot(data=data, x='is_paid')
plt.xlabel("Is paid?", fontsize=13)
plt.ylabel("Count", fontsize=13)
plt.show()

# %% [markdown]
# ## 9. Which course has more lectures Free or Paid courses?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.groupby('is_paid')['num_lectures'].mean()
# Out:
# is_paid
# False    21.416129
# True     41.866746
# Name: num_lectures, dtype: float64

# %% [markdown]
# ## 10. Which courses have a higher number of subscribers Free or Paid?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.groupby('is_paid')['num_subscribers'].mean()
# Out:
# is_paid
# False    11533.951613
# True      2421.270077
# Name: num_subscribers, dtype: float64

# %%
sns.barplot(x='is_paid', y='num_subscribers',data=data)
plt.xlabel("Is paid?", fontsize=13)
plt.ylabel("Subscribers", fontsize=13)
plt.show()

# %% [markdown]
# ## 11. Which level has the highest number of subscribers?

# %%
data.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6871791
# Beginner Level        4051843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
sns.barplot(x='level', y='num_subscribers', data=data)
plt.xlabel('Level', fontsize=13)
plt.ylabel('Sub Count', fontsize=13)
plt.show()

# %% [markdown]
# ## 12. Find Most Popular Course Title

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.sort_values(by='num_subscribers', ascending=False).iloc[0]['course_title']
# Out:
# 'Learn HTML5 Programming From Scratch'

# %%
# Alternatively
data[data['num_subscribers'] == data['num_subscribers'].max()]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# ## 13. Display 10 most popular courses as per the number of subscribers

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.sort_values(by='num_subscribers', ascending=False).head(10)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# 1896      19421              Free Beginner Electric Guitar Lessons
# 2589     473160  Web Design for Web Developers: Build Beautiful...
# 2619      94430             Learn Javascript & JQuery From Scratch
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...
# 3247     364426          JavaScript: Understanding the Weird Parts
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# ...

# %%
sns.barplot(x='num_subscribers', y='course_title', data=data.sort_values(by='num_subscribers', ascending=False).head(10))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 15. The course with the highest number of reviews

# %%
data[data['num_reviews'] == data['num_reviews'].max()]['course_title']
# Out:
# 3230    The Web Developer Bootcamp
# Name: course_title, dtype: object

# %%
data.sort_values(by='num_reviews', ascending=False).iloc[0]['course_title']
# Out:
# 'The Web Developer Bootcamp'

# %%
sns.barplot(x='num_reviews', y='course_title', data=data.sort_values(by='num_reviews', ascending=False).head())
plt.show()

# %% [markdown]
# ## 17. Does price affect the number of reviews?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
sns.lineplot(data=data, x='price', y='num_reviews')
plt.show()

# %%
sns.scatterplot(x='price', y='num_reviews', data=data)
plt.show()

# %% [markdown]
# ## 18. Total number of courses related to python

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
sum(data['course_title'].str.contains('python', case=False))
# Out:
# 29

# %% [markdown]
# ## 19. Display 10 most popular python courses as per number of subscribers

# %%
data[data['course_title'].str.contains('python', case=False)].sort_values(by='num_subscribers', ascending=False).head(10)['course_title']
# Out:
# 2497                          Web Programming with Python
# 2570    Coding for Entrepreneurs: Learn Python, Django...
# 2528          Learn Python and Django: Payment Processing
# 3200    Python and Django Full Stack Web Developer Boo...
# 3507    Fun and creative web engineering with Python a...
# 2553    The Complete Ethical Hacking Course 2.0: Pytho...
# 3138    Complete Python Web Course: Build 8 Python Web...
# 3197    Try Django 1.9 | Build a Blog and Learn Python...
# 2681    Python for Beginners: Python Programming Langu...
# 3203                      REST APIs with Flask and Python
# Name: course_title, dtype: object

# %%
df = data[data['course_title'].str.contains('python', case=False)].sort_values(by='num_subscribers', ascending=False).head(10)

# %%
sns.barplot(data=df, x='num_subscribers', y='course_title')
plt.show()

# %% [markdown]
# ## 20. In which year the highest number of courses were posted?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject
# 0 2017-01-18 20:58:58+00:00  Business Finance

# %%
data.insert(loc=11, column='year', value=data['published_timestamp'].dt.year)
data.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp  year           subject
# 0 2017-01-18 20:58:58+00:00  2017  Business Finance

# %%
data['year'].value_counts()
# Out:
# year
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: count, dtype: int64

# %%
sns.countplot(x='year', data=data)
plt.show()

# %% [markdown]
# ## 21. Display count of posted subjects year-wise

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'year', 'subject'],
#       dtype='object')

# %%
data.groupby('year')['subject'].value_counts()
# Out:
# year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       223
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64
